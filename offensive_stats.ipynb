# %%
import pandas as pd
from tabulate import tabulate

# Load the data
file_path = '/Users/vrishfish/Mens-Soccer-Stats-1/Datasets/player-combined-data.csv'  
data = pd.read_csv(file_path)

# Calculate accuracy percentages
data['Pass Accuracy (%)'] = (data['total_passes_completed'] / data['total_passes']) * 100
data['Long Pass Accuracy (%)'] = (data['long_passes_completed'] / data['long_passes']) * 100
data['Cross Accuracy (%)'] = (data['accurate_crosses'] / data['crosses']) * 100
data['Dribble Accuracy (%)'] = (data['successful_dribbles'] / data['dribbles']) * 100
data['Foul Percentage (%)'] = (data['fouls_drawn'] / data['offensive_duels']) * 100
# data['Offensive Duels Won (%)'] = (data['offensive_duels_won'] / data['offensive_duels']) * 100

# Handle division by zero or NaN
accuracy_features = [
    'Pass Accuracy (%)', 'Long Pass Accuracy (%)', 'Cross Accuracy (%)',
    'Dribble Accuracy (%)', 'Foul Percentage (%)'
]
data[accuracy_features] = data[accuracy_features].fillna(0)

# Group by player and position to aggregate statistics
# Include only numeric columns for grouping
numeric_columns = data.select_dtypes(include='number').columns.tolist()
player_position_stats = data.groupby(['player_name', 'Position'])[numeric_columns].mean().reset_index()

# Calculate quartiles for accuracy metrics
quartiles = player_position_stats[accuracy_features].quantile([0.25, 0.75]).T
quartiles.columns = ['25th_percentile', '75th_percentile']

# Identify strengths and weaknesses
def evaluate_strengths_weaknesses(row):
    strengths = []
    weaknesses = []
    
    for feature in accuracy_features:
        if row[feature] >= quartiles.loc[feature, '75th_percentile']:
            strengths.append(feature)
        elif row[feature] <= quartiles.loc[feature, '25th_percentile']:
            weaknesses.append(feature)
    
    return pd.Series([', '.join(strengths), ', '.join(weaknesses)], index=['Strengths', 'Weaknesses'])

# Apply evaluation to determine strengths and weaknesses
player_position_stats[['Strengths', 'Weaknesses']] = player_position_stats.apply(evaluate_strengths_weaknesses, axis=1)

# Filter out rows where Position is 0
player_position_stats = player_position_stats[player_position_stats['Position'] != '0']


# Save results to a CSV
output_file = 'player_strengths_weaknesses.csv'
player_position_stats[['player_name', 'Position', 'Strengths', 'Weaknesses']].to_csv(output_file, index=False)

# Display a preview of the results
print(tabulate(player_position_stats[['player_name', 'Position', 'Strengths', 'Weaknesses']], headers='keys', tablefmt='grid', showindex=False))
# Out:
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | player_name       | Position                    | Strengths                                                                                                | Weaknesses                                                                                               |
# +===================+=============================+==========================================================================================================+==========================================================================================================+
# | A. Adalsteinsson  | CB                          | Long Pass Accuracy (%)                                                                                   | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Adalsteinsson  | CB, LCB                     | Long Pass Accuracy (%)                                                                                   | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Adalsteinsson  | CB, RCB                     | Cross Accuracy (%)                                                                                       | Dribble Accuracy (%), Foul Percentage (%)                                                                |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Adalsteinsson  | LCB                         | Pass Accuracy (%), Long Pass Accuracy (%)                                                                | Cross Accuracy (%), Foul Percentage (%)                                                                  |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Adalsteinsson  | LCB, RCB                    |                                                                                                          | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Adalsteinsson  | RCB                         | Pass Accuracy (%)                                                                                        | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Barger         | LB                          | Cross Accuracy (%), Foul Percentage (%)                                                                  |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Barger         | LB, LB5                     |                                                                                                          | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Barger         | LB, LWB                     | Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                         | Long Pass Accuracy (%)                                                                                   |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Barger         | LB, RB                      | Dribble Accuracy (%)                                                                                     | Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | AMF, CF, LW                 | Pass Accuracy (%), Long Pass Accuracy (%)                                                                | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | CF                          | Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                               | Dribble Accuracy (%)                                                                                     |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LAMF                        | Long Pass Accuracy (%), Foul Percentage (%)                                                              | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LAMF, RAMF                  |                                                                                                          | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LCMF, RW                    | Pass Accuracy (%), Long Pass Accuracy (%)                                                                | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LW                          | Pass Accuracy (%)                                                                                        |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LW, CF                      | Dribble Accuracy (%)                                                                                     | Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LW, RCMF3                   | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            | Dribble Accuracy (%), Foul Percentage (%)                                                                |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | LW, RW                      | Cross Accuracy (%), Foul Percentage (%)                                                                  |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | RAMF                        | Pass Accuracy (%), Dribble Accuracy (%)                                                                  |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | RAMF, RW                    | Pass Accuracy (%), Cross Accuracy (%)                                                                    |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | RCMF, RW                    | Cross Accuracy (%), Foul Percentage (%)                                                                  | Pass Accuracy (%), Dribble Accuracy (%)                                                                  |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | RW                          | Cross Accuracy (%), Foul Percentage (%)                                                                  |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Bilow          | RW, CF                      | Dribble Accuracy (%)                                                                                     | Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Braman         | GK                          | Pass Accuracy (%), Long Pass Accuracy (%)                                                                | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | AMF                         | Pass Accuracy (%), Cross Accuracy (%)                                                                    | Long Pass Accuracy (%)                                                                                   |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | AMF, CF                     |                                                                                                          | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | AMF, CF, RAMF               | Pass Accuracy (%), Dribble Accuracy (%)                                                                  | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | CF                          |                                                                                                          |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | CF, LW                      |                                                                                                          | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | CF, LW, RW                  | Pass Accuracy (%), Dribble Accuracy (%)                                                                  | Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | CF, LWB                     | Dribble Accuracy (%)                                                                                     | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | CF, RW                      |                                                                                                          | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | CF, RWF                     | Pass Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                             | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Camara         | RWF, CF                     | Dribble Accuracy (%)                                                                                     | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Cooke          | GK                          | Long Pass Accuracy (%), Foul Percentage (%)                                                              | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LB                          |                                                                                                          | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LB5                         |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%) |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LCB                         | Foul Percentage (%)                                                                                      | Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                                              |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LCB, LCB3                   | Dribble Accuracy (%)                                                                                     | Cross Accuracy (%), Foul Percentage (%)                                                                  |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LCB, RW                     |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%) |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LCB3                        | Foul Percentage (%)                                                                                      | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LCMF3                       | Foul Percentage (%)                                                                                      | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | LWB                         |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%) |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Flynn          | RCB                         |                                                                                                          | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | AMF                         | Cross Accuracy (%)                                                                                       | Long Pass Accuracy (%)                                                                                   |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | AMF, CF                     | Cross Accuracy (%)                                                                                       | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | AMF, RAMF                   | Pass Accuracy (%)                                                                                        | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | CF                          |                                                                                                          | Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | LW                          | Cross Accuracy (%), Dribble Accuracy (%)                                                                 | Pass Accuracy (%)                                                                                        |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | LW, CF                      | Dribble Accuracy (%)                                                                                     | Cross Accuracy (%), Foul Percentage (%)                                                                  |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | RW                          | Long Pass Accuracy (%)                                                                                   | Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                         |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Hall           | RW, CF                      | Cross Accuracy (%), Dribble Accuracy (%)                                                                 | Long Pass Accuracy (%), Foul Percentage (%)                                                              |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Kato           | CF                          |                                                                                                          | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Legaspi        | CB, RCB                     |                                                                                                          | Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                         |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Legaspi        | LCB3, RCB3                  | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            | Dribble Accuracy (%), Foul Percentage (%)                                                                |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Legaspi        | RB                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            | Foul Percentage (%)                                                                                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Legaspi        | RCB                         | Pass Accuracy (%)                                                                                        | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Legaspi        | RCB3                        | Foul Percentage (%)                                                                                      |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | AMF                         | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | DMF                         | Pass Accuracy (%)                                                                                        |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | DMF, LCMF                   | Pass Accuracy (%)                                                                                        | Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | DMF, RCMF3                  |                                                                                                          | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | DMF, RDMF                   | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | LCMF                        | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | LCMF, LCMF3                 | Pass Accuracy (%)                                                                                        | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | LCMF3, RCMF3                | Pass Accuracy (%), Long Pass Accuracy (%)                                                                | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | LDMF                        | Pass Accuracy (%), Dribble Accuracy (%)                                                                  | Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | RCMF                        | Pass Accuracy (%), Foul Percentage (%)                                                                   | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Narang         | RCMF3                       |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%) |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF                         | Pass Accuracy (%), Foul Percentage (%)                                                                   | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                                         |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF, LAMF                   | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                                         |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF, LCMF                   | Dribble Accuracy (%)                                                                                     | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF, LW                     |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF, RAMF                   |                                                                                                          | Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                         |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF, RCMF                   | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            | Dribble Accuracy (%), Foul Percentage (%)                                                                |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | AMF, RDMF                   | Dribble Accuracy (%), Foul Percentage (%)                                                                | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LAMF                        | Dribble Accuracy (%)                                                                                     | Pass Accuracy (%), Cross Accuracy (%)                                                                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LAMF, LDMF                  | Cross Accuracy (%)                                                                                       | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LCMF                        | Dribble Accuracy (%), Foul Percentage (%)                                                                | Pass Accuracy (%), Cross Accuracy (%)                                                                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LCMF, LW                    | Pass Accuracy (%), Foul Percentage (%)                                                                   | Long Pass Accuracy (%), Cross Accuracy (%)                                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LCMF, RCMF                  | Cross Accuracy (%)                                                                                       | Foul Percentage (%)                                                                                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LDMF, RAMF                  | Long Pass Accuracy (%)                                                                                   | Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                         |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | LDMF, RDMF                  | Pass Accuracy (%)                                                                                        | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | RAMF                        | Long Pass Accuracy (%)                                                                                   | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | RCMF                        |                                                                                                          | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Ndrenika       | RCMF, RW                    | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                                         | Foul Percentage (%)                                                                                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Nitzl          | AMF, LDMF                   | Pass Accuracy (%), Long Pass Accuracy (%)                                                                | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | A. Nitzl          | CB, DMF, LB, RDMF           | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# ...
# | W. Kulvik         | RCB3                        | Foul Percentage (%)                                                                                      | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | W. Nelson         | GK                          | Pass Accuracy (%), Long Pass Accuracy (%), Foul Percentage (%)                                           | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | W. Smith          | CF                          |                                                                                                          | Cross Accuracy (%)                                                                                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | CB                          | Pass Accuracy (%)                                                                                        | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | CB, RCB, RCB3               | Pass Accuracy (%)                                                                                        | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | CB, RCB3                    | Pass Accuracy (%), Long Pass Accuracy (%), Dribble Accuracy (%)                                          | Cross Accuracy (%), Foul Percentage (%)                                                                  |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | RB, RCB                     | Long Pass Accuracy (%)                                                                                   | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | RCB                         | Pass Accuracy (%), Long Pass Accuracy (%)                                                                |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | RCB, RCB3                   | Pass Accuracy (%), Long Pass Accuracy (%), Dribble Accuracy (%)                                          |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Y. Senden         | RCB3                        | Pass Accuracy (%)                                                                                        |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Babiak         | AMF                         | Foul Percentage (%)                                                                                      | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Babiak         | CF                          |                                                                                                          |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Kelly          | GK                          | Long Pass Accuracy (%), Foul Percentage (%)                                                              | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | CB                          | Pass Accuracy (%)                                                                                        | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | DMF, RCMF3                  |                                                                                                          | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | LCMF                        |                                                                                                          | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | LCMF, RCMF                  |                                                                                                          | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                    |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | LCMF, RDMF                  |                                                                                                          | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | LCMF3                       |                                                                                                          | Cross Accuracy (%), Dribble Accuracy (%), Foul Percentage (%)                                            |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | LDMF, RCMF, RDMF            | Dribble Accuracy (%)                                                                                     | Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                                               |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | RCMF                        | Foul Percentage (%)                                                                                      |                                                                                                          |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | RCMF, RW                    | Foul Percentage (%)                                                                                      | Long Pass Accuracy (%), Cross Accuracy (%), Dribble Accuracy (%)                                         |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Martens        | RCMF3                       | Foul Percentage (%)                                                                                      | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | AMF                         | Foul Percentage (%)                                                                                      | Cross Accuracy (%), Dribble Accuracy (%)                                                                 |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | LAMF                        | Cross Accuracy (%)                                                                                       | Pass Accuracy (%), Foul Percentage (%)                                                                   |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | LAMF, LW                    | Dribble Accuracy (%)                                                                                     | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | LAMF, RAMF                  |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | LW                          |                                                                                                          | Foul Percentage (%)                                                                                      |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | LW, RW                      | Cross Accuracy (%), Foul Percentage (%)                                                                  | Dribble Accuracy (%)                                                                                     |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+
# | Z. Ramsey         | RAMF                        |                                                                                                          | Pass Accuracy (%), Long Pass Accuracy (%), Cross Accuracy (%), Foul Percentage (%)                       |
# +-------------------+-----------------------------+----------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+

# %% [markdown]
# *Comparing stats of winning vs losing teams*
#
# taking the teams which won and lost and comparing the statistics between them

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Drop goalkeeper stats and create a cleaned DataFrame
df = data.drop(columns=[
    'gk_stat_conceded_goals', 'gk_stat_xcg', 'gk_stat_shots_against', 
    'gk_stat_saves', 'gk_stat_reflex_saves', 'gk_stat_box_exits', 
    'gk_stat_passes_to_gk', 'gk_stat_passes_to_gk_completed', 
    'gk_stat_goal_kicks_attempted', 'gk_stat_short_goal_kicks', 
    'gk_stat_long_goal_kicks', 'year'
])

matches = df['Match']  # Replace 'Match' with the actual column name containing match data

# Function to determine the winner
def determine_winner(match):
    try:
        # Split the match string into parts
        parts = match.rsplit(' ', 1)  # Split into teams and scores
        teams = parts[0].split(' - ')  # Split teams
        scores = list(map(int, parts[1].split(':')))  # Split scores and convert to integers
        
        if scores[0] > scores[1]:
            return f"Winner: {teams[0]}"
        elif scores[0] < scores[1]:
            return f"Winner: {teams[1]}"
        else:
            return "Draw"
    except (IndexError, ValueError):
        # Handle cases with missing or malformed data
        return "Invalid Match Format"

# Apply the function to the match column
df['Result'] = matches.apply(determine_winner)

# Display the updated DataFrame
print(df[['Match', 'Result']])




# Filter matches won and lost
matches_won = df[df['Result'].str.contains('Winner')]  # Matches the team won
matches_lost = df[~df['Result'].str.contains('Winner') & ~df['Result'].str.contains('Draw')]  # Matches the team lost

# Group player stats by 'team' for matches won and lost
# Selecting only numerical columns for grouping
numerical_columns = df.select_dtypes(include=['number']).columns
player_stats_won = matches_won.groupby('team')[numerical_columns].mean()  # Mean stats for matches won
player_stats_lost = matches_lost.groupby('team')[numerical_columns].mean()  # Mean stats for matches lost

# Combine stats for comparison
comparison = player_stats_won.subtract(player_stats_lost, fill_value=0)  # Difference in stats
comparison['Match Count (Won)'] = matches_won['team'].value_counts()  # Count of matches won
comparison['Match Count (Lost)'] = matches_lost['team'].value_counts()  # Count of matches lost

# Display comparison DataFrame
print("Comparison of stats between matches won and lost:")
print(comparison)

# Save results to a CSV
output_file = 'team_winning_losing_stats.csv'
comparison.to_csv(output_file, index=False)
# Out:
#                                                   Match  \
# 0     Maryland College Park Terrapins - UCLA Bruins 0:6
# 1                  UCLA Bruins - Washington Huskies 0:1
# 2                    UCLA Bruins - Indiana Hoosiers 1:2
# 3     Maryland College Park Terrapins - UCLA Bruins 1:1
# 4             Rutgers Scarlet Knights - UCLA Bruins 0:3
# ...                                                 ...
# 8630      Penn State Nittany Lion - Cornell Big Red 2:3
# 8631  Penn State Nittany Lion - St. Bonaventure Bonn...
# 8632  Penn State Nittany Lion - Pittsburgh Panthers 1:2
# 8633  Penn State Nittany Lion - Army West Point Blac...
# 8634       Clemson Tigers - Penn State Nittany Lion 3:0
#
#                                Result
# 0                 Winner: UCLA Bruins
# 1          Winner: Washington Huskies
# 2            Winner: Indiana Hoosiers
# 3                                Draw
# 4                 Winner: UCLA Bruins
# ...                               ...
# 8630          Winner: Cornell Big Red
# 8631  Winner: Penn State Nittany Lion
# 8632      Winner: Pittsburgh Panthers
# 8633  Winner: Penn State Nittany Lion
# 8634           Winner: Clemson Tigers
#
# [8635 rows x 2 columns]
# Comparison of stats between matches won and lost:
#                             Minutes played  total_actions  successful_actions  \
# team
# Air Force Falcons                12.229167       1.458333            0.875000
# Akron Zips                       20.818182      23.000000           18.909091
# Brown Bears                     -38.224806      -5.333333          -10.635659
# Butler Bulldogs                  90.000000      86.000000           57.000000
# CSUN Matadors                    72.625000      54.375000           33.541667
# ...                                    ...            ...                 ...
# West Virginia Mountaineers      -18.864706      -0.941176            5.229412
# Wisconsin Badgers                74.871069      47.751572           29.827044
# Wofford Terriers                 81.000000      43.565217           19.130435
# Xavier Musketeers                -1.657143       1.514286            3.757143
# Yale Bulldogs                    88.071429      63.821429           31.892857
#
#                                goals   assists     shots  shots_on_target  \
# team
# Air Force Falcons           0.375000  0.104167  1.083333         0.625000
# Akron Zips                  0.000000  0.000000  0.181818         0.000000
# Brown Bears                 0.325581  0.046512  0.054264         0.054264
# Butler Bulldogs             0.000000  0.000000  0.000000         0.000000
# CSUN Matadors               0.125000  0.041667  0.833333         0.333333
# ...                              ...       ...       ...              ...
# West Virginia Mountaineers  0.147059  0.029412 -0.729412        -0.194118
# Wisconsin Badgers           0.094340  0.037736  0.811321         0.273585
# Wofford Terriers            0.565217  0.043478  2.478261         1.478261
# Xavier Musketeers           0.057143  0.000000  0.628571         0.228571
# Yale Bulldogs               0.142857  0.285714  2.071429         0.642857
#
#                                   xg  total_passes  total_passes_completed  \
# team
# Air Force Falcons           0.306042      1.145833                1.270833
# Akron Zips                  0.020000     16.545455               15.818182
# Brown Bears                -0.110543     -6.767442               -3.519380
# Butler Bulldogs             0.000000     52.000000               43.000000
# CSUN Matadors               0.056250     28.333333               22.458333
# ...                              ...           ...                     ...
# West Virginia Mountaineers -0.194765      3.876471                7.729412
# Wisconsin Badgers           0.103365     26.559748               20.742138
# Wofford Terriers            0.494348     14.173913               11.043478
# Xavier Musketeers           0.076571      2.971429                3.657143
# Yale Bulldogs               0.161071     31.892857               19.392857
#
#                             ...  forward_passes.1  back_passes  back_passes.1  \
# team                        ...
# Air Force Falcons           ...          1.104167     0.541667       0.041667
# Akron Zips                  ...          4.727273     1.090909       1.090909
# Brown Bears                 ...         -3.341085     2.612403       2.651163
# Butler Bulldogs             ...         16.000000    13.000000      11.000000
# CSUN Matadors               ...          5.541667     4.333333       4.000000
# ...                         ...               ...          ...            ...
# West Virginia Mountaineers  ...         -0.458824    -0.747059      -0.864706
# Wisconsin Badgers           ...          7.273585     3.738994       3.465409
# Wofford Terriers            ...          1.391304     5.391304       4.913043
# Xavier Musketeers           ...         -1.728571     0.571429       0.757143
# Yale Bulldogs               ...          6.357143     5.392857       4.714286
#
#                             Pass Accuracy (%)  Long Pass Accuracy (%)  \
# team
# Air Force Falcons                   -0.110424                4.166667
# Akron Zips                          70.792231               53.787879
# Brown Bears                          6.852485              -23.360348
# Butler Bulldogs                     82.692308               50.000000
# CSUN Matadors                       77.914322               42.416056
# ...                                       ...                     ...
# West Virginia Mountaineers           6.509055               17.968552
# Wisconsin Badgers                   76.329732               35.296330
# Wofford Terriers                    76.226820               17.391304
# Xavier Musketeers                   15.843350               20.533245
# Yale Bulldogs                       60.782050               40.380849
#
#                             Cross Accuracy (%)  Dribble Accuracy (%)  \
# team
# Air Force Falcons                     8.333333            -32.812500
# Akron Zips                            9.090909              0.000000
# Brown Bears                         -23.062016             -3.793706
# Butler Bulldogs                       0.000000              0.000000
# CSUN Matadors                         0.833333             47.222222
# ...                                        ...                   ...
# West Virginia Mountaineers            5.882353            -32.058824
# Wisconsin Badgers                    15.262429             32.565014
# Wofford Terriers                     26.811594             41.325052
# Xavier Musketeers                    10.000000             12.666667
# Yale Bulldogs                        33.103741             62.713754
#
#                             Foul Percentage (%)  Match Count (Won)  \
# team
# Air Force Falcons                     -9.931473                 48
# Akron Zips                             0.000000                 11
# Brown Bears                                 inf                 43
# Butler Bulldogs                       11.111111                  1
# CSUN Matadors                         15.405093                 24
# ...                                         ...                ...
# West Virginia Mountaineers                  inf                 34
# Wisconsin Badgers                           inf                318
# Wofford Terriers                      10.106685                 23
# Xavier Musketeers                           inf                 35
# Yale Bulldogs                         12.271503                 28
#
#                             Match Count (Lost)
# team
# Air Force Falcons                          3.0
# Akron Zips                                 NaN
# Brown Bears                                3.0
# Butler Bulldogs                            NaN
# CSUN Matadors                              NaN
# ...                                        ...
# West Virginia Mountaineers                 5.0
# Wisconsin Badgers                          NaN
# Wofford Terriers                           NaN
# Xavier Musketeers                          2.0
# Yale Bulldogs                              NaN
#
# [62 rows x 64 columns]
